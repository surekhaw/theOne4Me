# %%
import pandas as pd

# %%
dog_data = pd.read_csv('dog_breed_MBTI.csv')
dog_data
# Out:
#    dog_MBTI                                    dog_personality  Unnamed: 2  \
# 0      ISTJ  Quiet, serious, earn success by thoroughness a...         NaN
# 1      ISFJ  Quiet, friendly, responsible, and conscientiou...         NaN
# 2      INFJ  Seek meaning and connection in ideas, relation...         NaN
# 3      INTJ  Have original minds and great drive for implem...         NaN
# 4      ISTP  Tolerant and flexible, quiet observers until a...         NaN
# 5      ISFP  Quiet, friendly, sensitive, and kind. Enjoy th...         NaN
# 6      INFP  Idealistic, loyal to their values and to peopl...         NaN
# 7      INTP  Seek to develop logical explanations for every...         NaN
# 8      ESTP  Flexible and tolerant, they take a pragmatic a...         NaN
# 9      ESFP  Outgoing, friendly, and accepting. Exuberant l...         NaN
# 10     ENFP  Warmly enthusiastic and imaginative. See life ...         NaN
# ...

# %%
dog_data_clean = dog_data.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'])
dog_data_clean
# Out:
#    dog_MBTI                                    dog_personality  \
# 0      ISTJ  Quiet, serious, earn success by thoroughness a...
# 1      ISFJ  Quiet, friendly, responsible, and conscientiou...
# 2      INFJ  Seek meaning and connection in ideas, relation...
# 3      INTJ  Have original minds and great drive for implem...
# 4      ISTP  Tolerant and flexible, quiet observers until a...
# 5      ISFP  Quiet, friendly, sensitive, and kind. Enjoy th...
# 6      INFP  Idealistic, loyal to their values and to peopl...
# 7      INTP  Seek to develop logical explanations for every...
# 8      ESTP  Flexible and tolerant, they take a pragmatic a...
# 9      ESFP  Outgoing, friendly, and accepting. Exuberant l...
# 10     ENFP  Warmly enthusiastic and imaginative. See life ...
# 11     ENTP  Quick, ingenious, stimulating, alert, and outs...
# 12     ESTJ  Practical, realistic, matter-of-fact. Decisive...
# 13     ESFJ  Warmhearted, conscientious, and cooperative. W...
# ...

# %%
print(dog_data_clean.iloc[0,1])
# Out:
# Quiet, serious, earn success by thoroughness and dependability. Practical, matter-of-fact, realistic, and responsible. Decide logically what should be done and work toward it steadily, regardless of distractions. Take pleasure in making everything orderly and organized - their work, their home, their life. Value traditions and loyalty.

# %%
dog_data_clean.to_csv('./dog_data_clean')

# %%
index = dog_data_clean[dog_data_clean['dog_MBTI']== 'INTJ'].index.values
print(index)
# 		perfect_dog = dog_data_clean['dog_breed']
# 		perfect_dog_personality = dog_data_clean['dog_personality']
# 		print(f'Your perfect dog match is {perfect_dog}. Your dog is {perfect_dog_personality}.')
# print(df[df[‘Name’]==’Donna’].index.values)
# Out:
# [3]
